# %% [markdown]
# <h1 style="background-color: gray;
#            color: black;
#            padding: 20px;
#            text-align: center;">INFO</h1>
#
# In this script, we compare players `Random1`, `Random2` and `Random3` in a game where there is only one cheese to catch in a maze without mud. \
# All programs are evaluated on the same game configurations. \
# We do not show the game interface here, to make the script faster. \
# The goal is to compare the performances of the different random players in the same conditions.

# %% [markdown]
# <h1 style="background-color: gray;
#            color: black;
#            padding: 20px;
#            text-align: center;">IMPORTS</h1>

# %%
# External imports
import sys
import os
import tqdm.auto as tqdm
import matplotlib.pyplot as pyplot
import scipy.stats as scstats

# Add needed directories to the path
sys.path.append(os.path.join("..", "players"))

# PyRat imports
from pyrat import Game, GameMode
from Random1 import Random1
from Random2 import Random2
from Random3 import Random3
from Random4 import Random4
from Random5 import Random5
from BFS import BFS
from DFS import DFS
from Dijikstra import Dijikstra

# %% [markdown]
# <h1 style="background-color: gray;
#            color: black;
#            padding: 20px;
#            text-align: center;">CONSTANTS</h1>
#
# In this script, we are going to make multiple independent games. \
# The goal is to collect enough statistics to draw conclusions on which algorithm is better than the other. \
# This constant defines how many games are made.

# %%
# Determines how many games will be played for each player
NB_GAMES = 50

# %% [markdown]
# Let's configure the game with a dictionary. \
# Note that we put the game mode as `SIMULATION` to perform all games as fast as possible.

# %%
# Customize the game elements
CONFIG = {"mud_percentage": 20.0,
          "nb_cheese": 1,
          "game_mode": GameMode.SIMULATION}

# %% [markdown]
# <h1 style="background-color: gray;
#            color: black;
#            padding: 20px;
#            text-align: center;">RUN THE GAMES</h1>
#
# Let us now perform all games. \
# For each game, we remember the number of turns needed to complete it.

# %%
# Players to test (keys are legends to appear in the plot)
players = {
    "Random 3": {"class": Random3, "args": {}},
    "Random 4": {"class": Random4, "args": {}},
    "Random 5": {"class": Random5, "args": {}},
    "BFS": {"class": BFS, "args": {}},
    "DFS": {"class": DFS, "args": {}},
    "Dijikstra": {"class": Dijikstra, "args": {}},
}
# Run the games for each player
results = {player: [] for player in players}
for key in players:
    for seed in tqdm.tqdm(range(NB_GAMES), desc=key):
        
        # Make the game with given seed
        game = Game(random_seed=seed, **CONFIG)
        player = players[key]["class"](**players[key]["args"])
        game.add_player(player)
        stats = game.start()
        
        # Store the number of turns needed
        results[key].append(stats["turns"])
# Out:
# Random 3: 100%|██████████| 50/50 [00:27<00:00,  1.83it/s]
# Random 4: 100%|██████████| 50/50 [00:08<00:00,  6.20it/s]
# Random 5: 100%|██████████| 50/50 [00:07<00:00,  7.05it/s]
# BFS:   8%|▊         | 4/50 [00:00<00:02, 16.72it/s]
# Constructor
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 12
# Turn 13
# Turn 14
# Turn 20
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 11
# Turn 12
# Turn 13
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Turn 7
# Turn 8
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>]
# Turn 1
# Turn 2
# Turn 7
# Turn 16
# Turn 17
# Turn 22
# Turn 23
# Turn 24
# Turn 25
# Turn 26
# Turn 27
# Turn 28
# Turn 29
# Postprocessing
# BFS:  16%|█▌        | 8/50 [00:00<00:02, 15.54it/s]
# Constructor
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>]
# Turn 1
# Turn 8
# Turn 9
# Turn 10
# Turn 11
# Turn 12
# Turn 13
# Turn 20
# Turn 21
# Turn 22
# Turn 23
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Turn 14
# Turn 18
# Turn 19
# Turn 20
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>]
# Turn 1
# Turn 5
# Turn 6
# Turn 7
# Turn 8
# Turn 9
# Postprocessing
# BFS:  20%|██        | 10/50 [00:00<00:02, 16.18it/s]
# Constructor
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>]
# Turn 1
# Turn 2
# Turn 7
# Turn 8
# Turn 9
# Turn 14
# Turn 15
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Turn 7
# Turn 8
# Turn 9
# Turn 14
# Turn 15
# Turn 16
# Turn 17
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>]
# Turn 1
# Turn 9
# Turn 10
# Turn 11
# Turn 12
# Turn 13
# Turn 14
# Turn 15
# Turn 16
# Turn 17
# Turn 18
# Turn 26
# Postprocessing
# BFS:  28%|██▊       | 14/50 [00:00<00:02, 13.75it/s]
# Constructor
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>]
# Turn 1
# Turn 2
# Turn 11
# Turn 19
# Turn 20
# Turn 25
# Turn 26
# Turn 27
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>]
# Turn 1
# Turn 2
# Turn 10
# Turn 11
# Turn 19
# Turn 20
# Turn 21
# Turn 22
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 12
# Turn 13
# Turn 14
# Turn 15
# Turn 23
# Turn 24
# Turn 25
# Turn 26
# Turn 27
# Turn 28
# Turn 29
# Postprocessing
# BFS:  32%|███▏      | 16/50 [00:01<00:02, 14.18it/s]
# Constructor
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 7
# Turn 8
# Turn 17
# Turn 18
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>]
# Turn 1
# Turn 2
# Turn 6
# Turn 15
# Turn 24
# Turn 25
# Turn 26
# Turn 27
# Turn 28
# Turn 29
# Turn 30
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 11
# Turn 12
# Turn 13
# Turn 22
# Turn 23
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>]
# Turn 1
# Turn 2
# Turn 10
# BFS:  40%|████      | 20/50 [00:01<00:02, 13.98it/s]
# Turn 11
# Turn 12
# Turn 13
# Turn 19
# Turn 20
# Turn 21
# Turn 22
# Turn 23
# Turn 24
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Turn 11
# Turn 12
# Turn 13
# Turn 20
# Turn 21
# Turn 22
# Turn 28
# Turn 29
# Turn 34
# Turn 35
# Turn 36
# Turn 37
# Turn 38
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>]
# Turn 1
# Turn 8
# Turn 9
# Turn 10
# Turn 11
# Turn 12
# Turn 18
# Turn 24
# Turn 25
# Turn 26
# Turn 32
# Turn 40
# Turn 41
# Turn 42
# Turn 43
# Turn 44
# Postprocessing
# BFS:  44%|████▍     | 22/50 [00:01<00:02, 13.84it/s]
# Constructor
# Preprocessing
# Computed Actions: [<Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 9
# Turn 10
# Turn 15
# Turn 16
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 12
# Turn 20
# Turn 29
# Turn 30
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>]
# Turn 1
# Turn 7
# Turn 8
# Turn 9
# Turn 10
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# BFS:  52%|█████▏    | 26/50 [00:01<00:01, 15.59it/s]
# Turn 14
# Turn 15
# Turn 16
# Turn 17
# Turn 26
# Turn 27
# Turn 34
# Turn 35
# Turn 36
# Turn 37
# Turn 38
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Turn 7
# Turn 8
# Turn 12
# Turn 13
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.SOUTH: 'south'>]
# Turn 1
# Turn 2
# Postprocessing
# Constructor
# BFS:  60%|██████    | 30/50 [00:01<00:01, 16.36it/s]
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>]
# Turn 1
# Turn 2
# Turn 9
# Turn 10
# Turn 11
# Turn 12
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Turn 15
# Turn 16
# Turn 17
# Turn 18
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 10
# BFS:  68%|██████▊   | 34/50 [00:02<00:01, 15.37it/s]
# Turn 11
# Turn 12
# Turn 17
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Turn 7
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>]
# Turn 1
# Turn 10
# Turn 11
# Turn 12
# Turn 18
# Turn 25
# Turn 26
# Turn 27
# Turn 28
# Turn 29
# Turn 30
# Turn 31
# Turn 32
# Turn 33
# Turn 34
# Turn 35
# Turn 36
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>]
# Turn 1
# Turn 9
# Turn 10
# Turn 11
# Turn 18
# Turn 19
# Turn 20
# Turn 25
# Turn 26
# Postprocessing
# BFS:  76%|███████▌  | 38/50 [00:02<00:00, 15.86it/s]
# Constructor
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>]
# Turn 1
# Turn 2
# Turn 6
# Turn 7
# Turn 8
# Turn 12
# Turn 16
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>]
# Turn 1
# Turn 2
# Turn 7
# Turn 8
# Turn 9
# Turn 10
# Turn 11
# Turn 12
# Turn 13
# Turn 14
# Turn 15
# Turn 16
# Turn 17
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 11
# Turn 16
# Turn 17
# Turn 18
# Turn 26
# Postprocessing
# BFS:  84%|████████▍ | 42/50 [00:02<00:00, 16.51it/s]
# Constructor
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>]
# Turn 1
# Turn 2
# Turn 10
# Turn 16
# Turn 17
# Turn 18
# Turn 19
# Turn 20
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>]
# Turn 1
# Turn 2
# Turn 3
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Turn 7
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>]
# Turn 1
# Turn 2
# Turn 11
# Turn 12
# Turn 16
# Turn 17
# Postprocessing
# BFS:  88%|████████▊ | 44/50 [00:02<00:00, 15.37it/s]
# Constructor
# Preprocessing
# Computed Actions: [<Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Turn 7
# Turn 12
# Turn 13
# Turn 14
# Turn 15
# Turn 16
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>]
# Turn 1
# Turn 6
# Turn 7
# Turn 8
# Turn 9
# Turn 10
# Turn 11
# Turn 12
# Turn 13
# Turn 14
# Turn 21
# Turn 22
# Turn 23
# Turn 24
# Turn 25
# Turn 26
# Turn 27
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>]
# Turn 1
# Turn 2
# Turn 10
# Turn 18
# Turn 19
# Turn 20
# Turn 21
# Turn 22
# Turn 27
# Turn 28
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>]
# Turn 1
# Turn 2
# BFS:  96%|█████████▌| 48/50 [00:03<00:00, 15.06it/s]
# Turn 7
# Turn 8
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 9
# Turn 10
# Turn 11
# Turn 12
# Turn 13
# Turn 20
# Turn 21
# Turn 22
# Turn 23
# Turn 24
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 13
# Turn 14
# Turn 15
# Turn 16
# Turn 17
# Turn 18
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Turn 7
# Turn 8
# Turn 9
# Turn 10
# Turn 11
# BFS: 100%|██████████| 50/50 [00:03<00:00, 15.27it/s]
# Turn 12
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Turn 7
# Turn 8
# Turn 9
# Turn 10
# Turn 11
# Turn 12
# Postprocessing
# DFS:   2%|▏         | 1/50 [00:00<00:05,  9.16it/s]
# Constructor
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 13
# Turn 17
# Turn 18
# Turn 19
# Turn 20
# Turn 21
# Turn 22
# Turn 23
# Turn 24
# Turn 25
# Turn 29
# Turn 30
# Turn 37
# Turn 46
# Turn 47
# Turn 52
# Turn 53
# Turn 54
# Turn 55
# Turn 56
# Turn 64
# Turn 65
# Turn 66
# Turn 67
# Turn 73
# Turn 79
# Turn 80
# Turn 86
# Turn 87
# Turn 88
# Turn 89
# Turn 90
# Turn 91
# Turn 97
# Turn 98
# Turn 103
# Turn 104
# Turn 105
# Turn 106
# Turn 107
# Turn 108
# Turn 109
# Turn 110
# Turn 111
# Turn 117
# Turn 118
# Turn 119
# Postprocessing
# DFS:   4%|▍         | 2/50 [00:00<00:05,  9.02it/s]
# Constructor
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>]
# Turn 1
# Turn 2
# Turn 8
# Turn 9
# Turn 10
# Turn 18
# Turn 22
# Turn 29
# Turn 30
# Turn 31
# Turn 32
# Turn 33
# Turn 39
# Turn 40
# Turn 41
# Turn 45
# Turn 46
# Turn 47
# Turn 54
# Turn 59
# Turn 60
# Turn 61
# Turn 68
# Turn 73
# Turn 80
# Turn 81
# Turn 82
# Turn 83
# Turn 88
# Turn 89
# Turn 90
# Turn 96
# Turn 97
# Turn 98
# Turn 99
# Turn 108
# Turn 109
# Turn 115
# Turn 116
# Turn 117
# Turn 118
# Turn 119
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>]
# Turn 1
# Turn 6
# Turn 7
# Turn 8
# Turn 9
# Turn 10
# Turn 11
# Turn 20
# Turn 24
# Turn 25
# Turn 26
# Turn 27
# Turn 36
# Turn 37
# Turn 38
# Turn 39
# Turn 40
# Turn 41
# Turn 42
# Turn 43
# Turn 44
# Turn 45
# Turn 46
# Turn 47
# Turn 48
# Turn 49
# Turn 50
# Turn 55
# Turn 56
# Turn 57
# Turn 58
# Turn 59
# Turn 65
# Turn 72
# Turn 79
# Turn 80
# Turn 85
# Turn 86
# Turn 95
# Turn 96
# Turn 97
# Turn 98
# Turn 99
# Turn 104
# Postprocessing
# Constructor
# DFS:   8%|▊         | 4/50 [00:00<00:04, 10.42it/s]
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 13
# Turn 18
# Turn 19
# Turn 20
# Turn 25
# Turn 26
# Turn 27
# Turn 28
# Turn 29
# Turn 30
# Turn 36
# Turn 44
# Turn 45
# Turn 46
# Turn 47
# Turn 54
# Turn 55
# Turn 56
# Turn 57
# Turn 58
# Turn 59
# Turn 60
# Turn 61
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>]
# Turn 1
# Turn 8
# Turn 9
# Turn 10
# Turn 18
# Turn 19
# Turn 20
# Turn 28
# Turn 29
# Turn 30
# Turn 31
# Turn 32
# Turn 33
# Turn 34
# Turn 35
# Turn 36
# Turn 37
# Turn 38
# Turn 45
# Turn 46
# DFS:  12%|█▏        | 6/50 [00:00<00:03, 11.35it/s]
# Turn 47
# Turn 48
# Turn 49
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Turn 14
# Turn 19
# Turn 25
# Turn 30
# Turn 38
# Turn 39
# Turn 40
# Turn 41
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 12
# Turn 21
# Turn 22
# Turn 29
# Turn 30
# Turn 31
# Turn 32
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>]
# Turn 1
# Turn 5
# Turn 6
# Turn 13
# Turn 14
# Turn 15
# Turn 16
# DFS:  16%|█▌        | 8/50 [00:00<00:03, 11.77it/s]
# Turn 17
# Turn 18
# Turn 26
# Turn 34
# Turn 41
# Turn 47
# Turn 48
# Turn 49
# Turn 50
# Turn 58
# Turn 59
# Turn 60
# Turn 64
# Turn 65
# Turn 66
# Turn 71
# Turn 72
# Turn 73
# Turn 74
# Turn 75
# Turn 80
# Turn 81
# Turn 82
# Turn 83
# Turn 84
# Turn 85
# Turn 86
# Turn 87
# Turn 88
# Turn 97
# Turn 105
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Turn 7
# Turn 8
# Turn 9
# Turn 10
# Turn 11
# Turn 12
# Turn 13
# Turn 14
# Turn 20
# Turn 24
# Turn 25
# Turn 26
# Turn 27
# Turn 36
# Turn 37
# Turn 38
# Turn 39
# Turn 40
# Turn 41
# Turn 42
# Turn 43
# Turn 44
# Turn 52
# Turn 53
# Turn 54
# Turn 55
# Turn 56
# Turn 61
# Turn 62
# Turn 63
# Turn 68
# Turn 73
# Turn 74
# Turn 75
# Turn 76
# Turn 77
# Turn 83
# Turn 84
# Turn 85
# Turn 86
# Turn 90
# Turn 96
# Turn 97
# Turn 98
# Turn 99
# Turn 100
# Turn 101
# Turn 102
# Turn 109
# Turn 110
# Turn 111
# Turn 112
# Turn 113
# Turn 114
# Turn 115
# Turn 116
# Turn 117
# Turn 125
# Turn 126
# Turn 131
# Turn 140
# Turn 141
# Turn 146
# Turn 147
# Turn 152
# Turn 153
# Turn 159
# Turn 163
# Turn 164
# Postprocessing
# Constructor
# DFS:  20%|██        | 10/50 [00:00<00:03, 10.75it/s]
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>]
# Turn 1
# Turn 2
# Turn 10
# Turn 11
# Turn 12
# Turn 13
# Turn 14
# Turn 15
# Turn 16
# Turn 17
# Turn 18
# Turn 25
# Turn 26
# Turn 27
# Turn 28
# Turn 35
# Turn 41
# Turn 42
# Turn 43
# Turn 44
# Turn 45
# Turn 51
# Turn 52
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>]
# Turn 1
# Turn 9
# Turn 10
# Turn 11
# Turn 12
# Turn 13
# Turn 14
# Turn 15
# Turn 16
# Turn 17
# Turn 18
# Turn 19
# Turn 20
# Turn 21
# Turn 25
# Turn 26
# Turn 27
# Turn 28
# Turn 29
# Turn 37
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>]
# Turn 1
# Turn 2
# Turn 11
# Turn 19
# Turn 20
# Turn 25
# Turn 26
# Turn 32
# Turn 33
# Turn 34
# Turn 41
# Turn 42
# Turn 46
# Turn 47
# Turn 48
# Turn 55
# Turn 56
# Turn 57
# DFS:  24%|██▍       | 12/50 [00:01<00:03, 10.64it/s]
# Turn 66
# Turn 67
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 10
# Turn 11
# Turn 12
# Turn 13
# Turn 14
# Turn 15
# Turn 16
# Turn 22
# Turn 23
# Turn 24
# Turn 25
# Turn 26
# Turn 27
# Turn 28
# Turn 36
# Turn 37
# Turn 38
# Turn 39
# Turn 40
# Turn 48
# Turn 49
# Turn 50
# Turn 51
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>]
# Turn 1
# Turn 10
# Turn 11
# Turn 12
# Turn 17
# Turn 18
# Turn 26
# Turn 27
# Turn 28
# Turn 29
# Turn 30
# Turn 31
# Turn 38
# Turn 42
# Turn 51
# Turn 52
# Turn 60
# Turn 65
# Turn 66
# Turn 67
# Turn 68
# Turn 69
# Turn 70
# Turn 71
# Turn 72
# Turn 73
# Turn 74
# Turn 75
# Turn 76
# Turn 77
# Turn 78
# Turn 87
# Turn 88
# Turn 96
# Turn 101
# Turn 102
# Turn 103
# Turn 104
# Turn 113
# Turn 114
# Turn 115
# Turn 120
# Turn 121
# DFS:  28%|██▊       | 14/50 [00:01<00:03,  9.93it/s]
# Turn 129
# Turn 130
# Turn 131
# Turn 132
# Turn 141
# Turn 142
# Turn 143
# Turn 144
# Turn 145
# Turn 146
# Turn 153
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>]
# Turn 1
# Turn 8
# Turn 9
# Turn 10
# Turn 19
# Turn 20
# Turn 21
# Turn 29
# Turn 30
# Turn 31
# Turn 32
# Turn 33
# Turn 34
# Turn 35
# Turn 36
# Turn 37
# Turn 38
# Turn 39
# Turn 40
# Turn 46
# Turn 47
# Turn 48
# Turn 49
# Turn 50
# Turn 58
# Turn 65
# Turn 66
# Turn 67
# Turn 68
# Turn 69
# Turn 70
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>]
# Turn 1
# Turn 5
# Turn 6
# Turn 11
# Turn 12
# Turn 13
# Turn 14
# Turn 23
# Turn 24
# Turn 32
# Turn 33
# Turn 34
# Turn 35
# Turn 36
# Turn 42
# Turn 43
# Turn 44
# Turn 45
# Turn 46
# Turn 47
# Turn 55
# Turn 63
# Turn 64
# Turn 65
# Turn 66
# Turn 75
# DFS:  36%|███▌      | 18/50 [00:01<00:02, 11.00it/s]
# Turn 84
# Turn 88
# Turn 89
# Turn 90
# Turn 96
# Turn 97
# Turn 101
# Turn 110
# Turn 119
# Turn 120
# Turn 121
# Turn 122
# Turn 123
# Turn 131
# Turn 132
# Turn 133
# Turn 134
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 11
# Turn 12
# Turn 13
# Turn 22
# Turn 23
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>]
# Turn 1
# Turn 8
# Turn 15
# Turn 16
# Turn 24
# Turn 25
# Turn 26
# Turn 27
# Turn 33
# Turn 40
# Turn 41
# Turn 42
# Turn 48
# Turn 49
# Turn 50
# Turn 51
# Postprocessing
# Constructor
# DFS:  40%|████      | 20/50 [00:01<00:03,  9.90it/s]
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 11
# Turn 18
# Turn 19
# Turn 20
# Turn 21
# Turn 22
# Turn 23
# Turn 24
# Turn 25
# Turn 26
# Turn 27
# Turn 28
# Turn 33
# Turn 34
# Turn 35
# Turn 36
# Turn 37
# Turn 38
# Turn 39
# Turn 40
# Turn 41
# Turn 47
# Turn 51
# Turn 52
# Turn 53
# Turn 60
# Turn 61
# Turn 62
# Turn 63
# Turn 64
# Turn 69
# Turn 70
# Turn 76
# Turn 85
# Turn 86
# Turn 91
# Turn 92
# Turn 93
# Turn 94
# Turn 100
# Turn 101
# Turn 102
# Turn 110
# Turn 115
# Turn 123
# Turn 124
# Turn 125
# Turn 131
# Turn 132
# Turn 133
# Turn 141
# Turn 142
# Turn 147
# Turn 148
# Turn 149
# Turn 150
# Turn 157
# Turn 158
# Turn 159
# Turn 160
# Turn 161
# Turn 162
# Turn 163
# Turn 164
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>]
# Turn 1
# Turn 8
# Turn 9
# Turn 10
# Turn 15
# Turn 16
# Turn 17
# Turn 18
# Turn 19
# Turn 20
# Turn 21
# Turn 25
# Turn 32
# Turn 33
# Turn 34
# Turn 35
# Turn 36
# Turn 37
# Turn 38
# Turn 39
# Turn 40
# Turn 41
# Turn 42
# Turn 43
# Turn 44
# Turn 49
# Turn 55
# Turn 62
# Turn 67
# Turn 68
# Turn 69
# Turn 70
# Turn 71
# Turn 72
# Turn 73
# Turn 81
# Turn 87
# Turn 95
# Turn 96
# Turn 97
# Turn 98
# Turn 102
# Turn 103
# Turn 104
# Turn 105
# Turn 110
# Turn 111
# Turn 112
# Postprocessing
# Constructor
# DFS:  44%|████▍     | 22/50 [00:02<00:02, 10.22it/s]
# Preprocessing
# Computed Actions: [<Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 9
# Turn 10
# Turn 15
# Turn 16
# Turn 17
# Turn 21
# Turn 30
# Turn 39
# Turn 40
# Turn 44
# Turn 50
# Turn 56
# Turn 57
# Turn 58
# Turn 59
# Turn 60
# Turn 61
# Turn 65
# Turn 73
# Turn 74
# Turn 75
# Turn 76
# Turn 77
# Turn 78
# Turn 87
# Turn 88
# Turn 89
# Turn 96
# Turn 102
# Turn 103
# Turn 104
# Turn 105
# Turn 106
# Turn 107
# Turn 115
# Turn 116
# Turn 117
# Turn 118
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 12
# Turn 20
# Turn 29
# Turn 30
# Turn 31
# Turn 40
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>]
# Turn 1
# Turn 7
# Turn 8
# Turn 17
# Turn 24
# Turn 31
# Turn 32
# Turn 38
# Turn 47
# Turn 56
# Turn 57
# Turn 58
# Turn 59
# Turn 60
# Turn 61
# Turn 62
# Turn 63
# Turn 67
# Turn 68
# Turn 69
# Turn 70
# Postprocessing
# DFS:  48%|████▊     | 24/50 [00:02<00:02,  9.95it/s]
# Constructor
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 7
# Turn 11
# Turn 18
# Turn 22
# Turn 23
# Turn 31
# Turn 32
# Turn 40
# Turn 45
# Turn 49
# Turn 58
# Turn 59
# Turn 60
# Turn 61
# Turn 62
# Turn 63
# Turn 64
# Turn 65
# Turn 66
# Turn 75
# Turn 76
# Turn 84
# Turn 90
# Turn 91
# Turn 92
# Turn 93
# Turn 97
# Turn 106
# Turn 107
# Turn 108
# Turn 109
# Turn 116
# Turn 117
# Turn 118
# Turn 119
# Turn 120
# Turn 121
# Turn 122
# Turn 123
# Turn 124
# Turn 125
# Turn 132
# Turn 133
# Turn 134
# Turn 141
# Turn 142
# Turn 143
# Turn 144
# Turn 145
# Turn 146
# Turn 153
# Turn 154
# Turn 155
# Turn 156
# Turn 157
# Turn 166
# Turn 167
# Turn 168
# Turn 174
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>]
# Turn 1
# Turn 6
# Turn 7
# Turn 8
# Turn 9
# Turn 10
# Turn 11
# Turn 12
# Turn 13
# Turn 18
# Turn 19
# Turn 28
# Turn 29
# Turn 30
# Turn 39
# Turn 40
# Turn 41
# Turn 49
# Turn 50
# Turn 51
# Turn 52
# Turn 57
# Turn 58
# Turn 59
# Postprocessing
# Constructor
# DFS:  52%|█████▏    | 26/50 [00:02<00:02, 10.04it/s]
# Preprocessing
# ...
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Turn 7
# Turn 8
# Turn 9
# Turn 10
# Turn 11
# Turn 12
# Turn 13
# Turn 21
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>]
# Turn 1
# Turn 2
# Turn 11
# Turn 12
# Turn 13
# Turn 14
# Turn 15
# Turn 16
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Turn 7
# Turn 8
# Turn 9
# Turn 10
# Turn 11
# Turn 12
# Turn 13
# Turn 14
# Turn 15
# Turn 16
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Turn 7
# Turn 8
# Turn 9
# Turn 17
# Turn 18
# Turn 19
# Turn 20
# Dijikstra:  32%|███▏      | 16/50 [00:01<00:02, 14.66it/s]
# Turn 21
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 7
# Turn 8
# Turn 12
# Turn 13
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>]
# Turn 1
# Turn 2
# Turn 8
# Turn 9
# Turn 10
# Turn 11
# Turn 12
# Turn 13
# Turn 14
# Turn 15
# Turn 16
# Postprocessing
# Dijikstra:  36%|███▌      | 18/50 [00:01<00:02, 14.40it/s]
# Constructor
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 11
# Turn 12
# Turn 13
# Turn 14
# Turn 15
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>]
# Turn 1
# Turn 2
# Turn 10
# Turn 11
# Turn 12
# Turn 13
# Turn 19
# Turn 20
# Turn 21
# Turn 22
# Turn 23
# Turn 24
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Turn 7
# Turn 12
# Turn 13
# Turn 14
# Turn 15
# Turn 16
# Turn 17
# Turn 18
# Turn 19
# Turn 20
# Turn 28
# Turn 29
# Turn 30
# Turn 31
# Turn 32
# Turn 33
# Turn 34
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>]
# Dijikstra:  44%|████▍     | 22/50 [00:01<00:02, 12.88it/s]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Turn 7
# Turn 8
# Turn 9
# Turn 10
# Turn 11
# Turn 17
# Turn 18
# Turn 19
# Turn 20
# Turn 21
# Turn 22
# Turn 23
# Turn 24
# Turn 25
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 9
# Turn 10
# Turn 15
# Turn 16
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 12
# Turn 13
# Turn 21
# Turn 22
# Turn 23
# Turn 24
# Postprocessing
# Dijikstra:  48%|████▊     | 24/50 [00:01<00:01, 13.52it/s]
# Constructor
# Preprocessing
# Computed Actions: [<Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 14
# Turn 15
# Turn 16
# Turn 17
# Turn 26
# Turn 27
# Turn 34
# Turn 35
# Turn 36
# Turn 37
# Turn 38
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Turn 7
# Turn 8
# Turn 12
# Turn 13
# Postprocessing
# Constructor
# Dijikstra:  56%|█████▌    | 28/50 [00:01<00:01, 14.89it/s]
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.SOUTH: 'south'>]
# Turn 1
# Turn 2
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Turn 7
# Turn 8
# Turn 9
# Turn 10
# Postprocessing
# Dijikstra:  64%|██████▍   | 32/50 [00:02<00:01, 14.99it/s]
# Constructor
# Preprocessing
# Computed Actions: [<Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Turn 12
# Turn 13
# Turn 14
# Turn 15
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Turn 7
# Turn 8
# Turn 9
# Turn 14
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Turn 7
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>]
# Dijikstra:  68%|██████▊   | 34/50 [00:02<00:01, 14.28it/s]
# Turn 1
# Turn 10
# Turn 11
# Turn 12
# Turn 13
# Turn 14
# Turn 15
# Turn 16
# Turn 17
# Turn 18
# Turn 19
# Turn 20
# Turn 21
# Turn 22
# Turn 23
# Turn 24
# Turn 25
# Turn 26
# Turn 27
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>]
# Turn 1
# Turn 6
# Turn 7
# Turn 8
# Turn 15
# Turn 16
# Turn 17
# Turn 18
# Turn 19
# Turn 20
# Turn 21
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 9
# Turn 10
# Turn 11
# Turn 12
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>]
# Dijikstra:  76%|███████▌  | 38/50 [00:02<00:00, 14.79it/s]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Turn 7
# Turn 8
# Turn 9
# Turn 10
# Turn 11
# Turn 12
# Turn 13
# Turn 14
# Turn 15
# Turn 16
# Turn 17
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Turn 11
# Turn 12
# Turn 13
# Turn 14
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>]
# Turn 1
# Turn 2
# Turn 10
# Turn 16
# Turn 17
# Turn 18
# Turn 19
# Turn 20
# Postprocessing
# Dijikstra:  84%|████████▍ | 42/50 [00:02<00:00, 15.46it/s]
# Constructor
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>]
# Turn 1
# Turn 2
# Turn 3
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Turn 7
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 9
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Turn 7
# Turn 12
# Turn 13
# Turn 14
# Turn 15
# Turn 16
# Postprocessing
# Dijikstra:  92%|█████████▏| 46/50 [00:03<00:00, 14.19it/s]
# Constructor
# Preprocessing
# Computed Actions: [<Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>]
# Turn 1
# Turn 6
# Turn 7
# Turn 8
# Turn 9
# Turn 10
# Turn 11
# Turn 12
# Turn 13
# Turn 14
# Turn 21
# Turn 22
# Turn 23
# Turn 24
# Turn 25
# Turn 26
# Turn 27
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>]
# Turn 1
# Turn 2
# Turn 9
# Turn 10
# Turn 11
# Turn 12
# Turn 13
# Turn 14
# Turn 19
# Turn 20
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>]
# Turn 1
# Turn 2
# Turn 7
# Turn 8
# Postprocessing
# Dijikstra:  96%|█████████▌| 48/50 [00:03<00:00, 13.75it/s]
# Constructor
# Preprocessing
# Computed Actions: [<Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.NORTH: 'north'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>, <Action.WEST: 'west'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Turn 7
# Turn 8
# Turn 9
# Turn 10
# Turn 11
# Turn 12
# Turn 13
# Turn 14
# Turn 15
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 13
# Turn 14
# Turn 15
# Turn 16
# Turn 17
# Turn 18
# Postprocessing
# Constructor
# Preprocessing
# Computed Actions: [<Action.WEST: 'west'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.NORTH: 'north'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Turn 7
# Turn 8
# Turn 9
# Turn 10
# Turn 11
# Turn 12
# Postprocessing
# Constructor
# Dijikstra: 100%|██████████| 50/50 [00:03<00:00, 14.47it/s]
# Preprocessing
# Computed Actions: [<Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.EAST: 'east'>, <Action.SOUTH: 'south'>]
# Turn 1
# Turn 2
# Turn 3
# Turn 4
# Turn 5
# Turn 6
# Turn 7
# Turn 8
# Turn 9
# Turn 10
# Turn 11
# Turn 12
# Postprocessing

# %% [markdown]
# <h1 style="background-color: gray;
#            color: black;
#            padding: 20px;
#            text-align: center;">ANALYZE THE RESULTS</h1>
#
# Now that all games are performed, we plot the percentage of games completed as a function of the number of turns elapsed.

# %%
# Visualization of cumulative curves of numbers of turns taken per program
max_turn = max([max(results[player]) for player in results])
pyplot.figure(figsize=(10, 5))
for player in results:
    turns = [0] + sorted(results[player]) + [max_turn]
    games_completed_per_turn = [len([turn for turn in results[player] if turn <= t]) * 100.0 / NB_GAMES for t in turns]
    pyplot.plot(turns, games_completed_per_turn, label=player)
pyplot.title("Comparison of turns needed to complete all %d games" % (NB_GAMES))
pyplot.xlabel("Turns per game")
pyplot.ylabel("% of games completed")
pyplot.xscale("log")
pyplot.legend()
pyplot.show()

# %% [markdown]
# Visualizing is great, but it may be hard to conclude with just a plot. \
# Here, we perform a statistical test that will give more insight on whether an algorithm is better than the other.

# %%
# Formal statistics to check if these curves are statistically significant
for i, player_1 in enumerate(results):
    for j, player_2 in enumerate(results):
        if j > i:
            test_result = scstats.mannwhitneyu(results[player_1], results[player_2], alternative="two-sided")
            print("Mann-Whitney U test between turns of program '%s' and of program '%s':" % (player_1, player_2), test_result)
# Out:
# Mann-Whitney U test between turns of program 'Random 3' and of program 'Random 4': MannwhitneyuResult(statistic=1519.0, pvalue=0.06416610641456004)
# Mann-Whitney U test between turns of program 'Random 3' and of program 'Random 5': MannwhitneyuResult(statistic=1645.0, pvalue=0.006534405600973427)
# Mann-Whitney U test between turns of program 'Random 3' and of program 'BFS': MannwhitneyuResult(statistic=2363.0, pvalue=1.7049561805539902e-14)
# Mann-Whitney U test between turns of program 'Random 3' and of program 'DFS': MannwhitneyuResult(statistic=1972.0, pvalue=6.553632590204781e-07)
# Mann-Whitney U test between turns of program 'Random 3' and of program 'Dijikstra': MannwhitneyuResult(statistic=2412.0, pvalue=1.154433112213556e-15)
# Mann-Whitney U test between turns of program 'Random 4' and of program 'Random 5': MannwhitneyuResult(statistic=1465.5, pvalue=0.1382888133478349)
# Mann-Whitney U test between turns of program 'Random 4' and of program 'BFS': MannwhitneyuResult(statistic=2438.0, pvalue=2.6672588660978052e-16)
# Mann-Whitney U test between turns of program 'Random 4' and of program 'DFS': MannwhitneyuResult(statistic=2047.0, pvalue=3.99343763819324e-08)
# Mann-Whitney U test between turns of program 'Random 4' and of program 'Dijikstra': MannwhitneyuResult(statistic=2446.5, pvalue=1.6317793453036115e-16)
# Mann-Whitney U test between turns of program 'Random 5' and of program 'BFS': MannwhitneyuResult(statistic=2303.5, pvalue=3.8535300324836233e-13)
# Mann-Whitney U test between turns of program 'Random 5' and of program 'DFS': MannwhitneyuResult(statistic=1842.5, pvalue=4.4777318340052366e-05)
# Mann-Whitney U test between turns of program 'Random 5' and of program 'Dijikstra': MannwhitneyuResult(statistic=2361.0, pvalue=1.8979967339192643e-14)
# Mann-Whitney U test between turns of program 'BFS' and of program 'DFS': MannwhitneyuResult(statistic=49.5, pvalue=1.294853071346326e-16)
# Mann-Whitney U test between turns of program 'BFS' and of program 'Dijikstra': MannwhitneyuResult(statistic=1594.0, pvalue=0.017779634132199976)
# Mann-Whitney U test between turns of program 'DFS' and of program 'Dijikstra': MannwhitneyuResult(statistic=2484.5, pvalue=1.7591808052916997e-17)
